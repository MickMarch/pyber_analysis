# %%
# %matplotlib ipympl

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os

# %%
pyber_df = pd.read_csv(os.path.join('..', 'resources', 'pyber_ride_data.csv'))
pyber_df.head()
# Out:
#    Month  Avg. Fare ($USD)
# 0    Jan             10.02
# 1    Feb             23.24
# 2    Mar             39.20
# 3  April             35.42
# 4    May             32.34

# %%
pyber_df.dtypes
# Out:
# Month                object
# Avg. Fare ($USD)    float64
# dtype: object

# %%
pyber_df.plot(x= "Month", y= "Avg. Fare ($USD)")
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
